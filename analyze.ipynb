# %%
import pandas as pd

# %%
lstm_combined_n5_normal = pd.read_csv("03_summarize/metricsn5/lstm_combined3/normal_var_basins.csv")
lstm_combined_n5_low = pd.read_csv("03_summarize/metricsn5/lstm_combined3/low_variance_basins.csv")

# %%
lstm_combined_n5_normal
# Out:
#                basin    std_obs       NSE      NNSE          MSE       RMSE  \
# 0            1013500   0.041322  0.265254  0.576453     0.001255   0.035420
# 1            1022500   7.180197  0.962950  0.964273     1.910143   1.382079
# 2            1030500   0.095784 -0.070838  0.482896     0.009825   0.099119
# 3            1031500   0.027411 -0.447655  0.408554     0.001088   0.032981
# 4            1052500   0.171862  0.867781  0.883222     0.003905   0.062492
# ..               ...        ...       ...       ...          ...        ...
# 512         14316700   6.644059  0.732224  0.788783    11.820563   3.438105
# 513         14325000   0.097592  0.582995  0.705714     0.003972   0.063021
# 514         14362250   0.080068  0.594338  0.711409     0.002601   0.050996
# 515         14400000  94.257121  0.761028  0.807120  2123.128017  46.077413
# 516  394220106431500   0.070981  0.346250  0.604686     0.003294   0.057391
#
# ...

# %%
lt_0 = lstm_combined_n5_normal[(lstm_combined_n5_normal["NSE"] < 0)].shape[0]
bt_0_25 = lstm_combined_n5_normal[(lstm_combined_n5_normal["NSE"] >= 0) & (lstm_combined_n5_normal["NSE"] < 0.25)].shape[0]
bt_25_50 = lstm_combined_n5_normal[(lstm_combined_n5_normal["NSE"] >= 0.25) & (lstm_combined_n5_normal["NSE"] < 0.5)].shape[0]
bt_50_75 = lstm_combined_n5_normal[(lstm_combined_n5_normal["NSE"] >= 0.5) & (lstm_combined_n5_normal["NSE"] < 0.75)].shape[0]
gt_75 = lstm_combined_n5_normal[(lstm_combined_n5_normal["NSE"] >= 0.75)].shape[0]

# %%
#plot pie chart of the percent of the above counts with the values included in the chart'
import matplotlib.pyplot as plt

labels = [f'Less than 0', f'0 - 0.25', f'0.25 - 0.5', f'0.5 - 0.75', f'0.75 - 1']
sizes = [lt_0, bt_0_25, bt_25_50, bt_50_75, gt_75]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'] 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.title('LSTM Combined Normal Variance Basins NSE Distribution')
plt.tight_layout()
plt.show()

# %%
lt_0_low = lstm_combined_n5_low[(lstm_combined_n5_low["NSE"] < 0)].shape[0]
gt_0 = lstm_combined_n5_low[(lstm_combined_n5_low["NSE"] >= 0)].shape[0]

# %%
#pie chart
labels = [f'< 0', f'> 0']
sizes = [lt_0_low, gt_0]
colors = ['#ff9999','#66b3ff'] 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.title('LSTM Combined Low Variance Basins NSE Distribution')
plt.tight_layout()
plt.show()

# %%
lstm_upstream_n5_normal = pd.read_csv("03_summarize/metricsn5/lstm_upstream3/normal_var_basins.csv")
lstm_upstream_n5_low = pd.read_csv("03_summarize/metricsn5/lstm_upstream3/low_variance_basins.csv")

# %%
lt_0 = lstm_upstream_n5_normal[(lstm_upstream_n5_normal["NSE"] < 0)].shape[0]
bt_0_25 = lstm_upstream_n5_normal[(lstm_upstream_n5_normal["NSE"] >= 0) & (lstm_upstream_n5_normal["NSE"] < 0.25)].shape[0]
bt_25_50 = lstm_upstream_n5_normal[(lstm_upstream_n5_normal["NSE"] >= 0.25) & (lstm_upstream_n5_normal["NSE"] < 0.5)].shape[0]
bt_50_75 = lstm_upstream_n5_normal[(lstm_upstream_n5_normal["NSE"] >= 0.5) & (lstm_upstream_n5_normal["NSE"] < 0.75)].shape[0]
gt_75 = lstm_upstream_n5_normal[(lstm_upstream_n5_normal["NSE"] >= 0.75)].shape[0]

# %%
labels = [f'Less than 0', f'0 - 0.25', f'0.25 - 0.5', f'0.5 - 0.75', f'0.75 - 1']
sizes = [lt_0, bt_0_25, bt_25_50, bt_50_75, gt_75]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'] 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.title('LSTM Upstream Normal Variance Basins NSE Distribution')
plt.tight_layout()
plt.show()

# %%
median_NSE_combined_upstream = [0.5458, 0.2100]
mean_NSE_combined_upstream = [-7.2, -2.39]

#plot bar chart comparing the median and mean NSE of combined and upstream models with the values

x = ['LSTM Combined', 'LSTM Upstream']
median_values = median_NSE_combined_upstream
mean_values = mean_NSE_combined_upstream
bar_width = 0.35
fig, ax = plt.subplots()
bars1 = ax.bar(x, median_values, bar_width, label='Median NSE', color='#66b3ff')
bars2 = ax.bar([i + bar_width for i in range(len(x))], mean_values, bar_width, label='Mean NSE', color='#ff9999')

# Add value labels on top of bars
for bar in bars1 + bars2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')
ax.set_ylabel('NSE Value')
ax.set_title('Median and Mean NSE Comparison between LSTM Combined and Upstream Models')
ax.legend()
plt.tight_layout()
plt.show()

# %%
lstm_combined_n10_normal = pd.read_csv("03_summarize/metricsn10/lstm_combined2/normal_var_basins.csv")
lstm_combined_n10_low = pd.read_csv("03_summarize/metricsn10/lstm_combined2/low_variance_basins.csv")

# %%
lt_0 = lstm_combined_n10_normal[(lstm_combined_n10_normal["NSE"] < 0)].shape[0]
bt_0_25 = lstm_combined_n10_normal[(lstm_combined_n10_normal["NSE"] >= 0) & (lstm_combined_n10_normal["NSE"] < 0.25)].shape[0]
bt_25_50 = lstm_combined_n10_normal[(lstm_combined_n10_normal["NSE"] >= 0.25) & (lstm_combined_n10_normal["NSE"] < 0.5)].shape[0]
bt_50_75 = lstm_combined_n10_normal[(lstm_combined_n10_normal["NSE"] >= 0.5) & (lstm_combined_n10_normal["NSE"] < 0.75)].shape[0]
gt_75 = lstm_combined_n10_normal[(lstm_combined_n10_normal["NSE"] >= 0.75)].shape[0]

# %%
#plot pie chart of the percent of the above counts with the values included in the chart'
import matplotlib.pyplot as plt

labels = [f'Less than 0', f'0 - 0.25', f'0.25 - 0.5', f'0.5 - 0.75', f'0.75 - 1']
sizes = [lt_0, bt_0_25, bt_25_50, bt_50_75, gt_75]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'] 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.title('LSTM Combined Normal Variance Basins NSE Distribution (n10)')
plt.tight_layout()
plt.show()

# %%
# Analysis for low variance basins
lt_0_low = lstm_combined_n10_low[(lstm_combined_n10_low["NSE"] < 0)].shape[0]
gt_0 = lstm_combined_n10_low[(lstm_combined_n10_low["NSE"] >= 0)].shape[0]

# %%
#pie chart for low variance basins
labels = [f'< 0', f'> 0']
sizes = [lt_0_low, gt_0]
colors = ['#ff9999','#66b3ff'] 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.title('LSTM Combined Low Variance Basins NSE Distribution (n10)')
plt.tight_layout()
plt.show()

# %%
# Load upstream data for n10
lstm_upstream_n10_normal = pd.read_csv("03_summarize/metricsn10/lstm_upstream1/normal_var_basins.csv")
lstm_upstream_n10_low = pd.read_csv("03_summarize/metricsn10/lstm_upstream1/low_variance_basins.csv")

# %%
# Calculate NSE distributions for upstream normal variance basins
lt_0 = lstm_upstream_n10_normal[(lstm_upstream_n10_normal["NSE"] < 0)].shape[0]
bt_0_25 = lstm_upstream_n10_normal[(lstm_upstream_n10_normal["NSE"] >= 0) & (lstm_upstream_n10_normal["NSE"] < 0.25)].shape[0]
bt_25_50 = lstm_upstream_n10_normal[(lstm_upstream_n10_normal["NSE"] >= 0.25) & (lstm_upstream_n10_normal["NSE"] < 0.5)].shape[0]
bt_50_75 = lstm_upstream_n10_normal[(lstm_upstream_n10_normal["NSE"] >= 0.5) & (lstm_upstream_n10_normal["NSE"] < 0.75)].shape[0]
gt_75 = lstm_upstream_n10_normal[(lstm_upstream_n10_normal["NSE"] >= 0.75)].shape[0]

# %%
# Plot pie chart for upstream normal variance basins
labels = [f'Less than 0', f'0 - 0.25', f'0.25 - 0.5', f'0.5 - 0.75', f'0.75 - 1']
sizes = [lt_0, bt_0_25, bt_25_50, bt_50_75, gt_75]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'] 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.title('LSTM Upstream Normal Variance Basins NSE Distribution (n10)')
plt.tight_layout()
plt.show()

# %%
# Calculate mean and median NSE for n10 models
# median_NSE_combined = lstm_combined_n10_normal['NSE'].median()
# mean_NSE_combined = lstm_combined_n10_normal['NSE'].mean()
# median_NSE_upstream = lstm_upstream_n10_normal['NSE'].median()
# mean_NSE_upstream = lstm_upstream_n10_normal['NSE'].mean()

median_NSE_combined_upstream = [0.4482, 0.2335]
mean_NSE_combined_upstream = [-11.3082, -198.4601 ]

# Plot bar chart comparing the median and mean NSE
x = ['LSTM Combined', 'LSTM Upstream']
median_values = median_NSE_combined_upstream
mean_values = mean_NSE_combined_upstream
bar_width = 0.35
fig, ax = plt.subplots()
bars1 = ax.bar(x, median_values, bar_width, label='Median NSE', color='#66b3ff')
bars2 = ax.bar([i + bar_width for i in range(len(x))], mean_values, bar_width, label='Mean NSE', color='#ff9999')

# Add value labels on top of bars
for bar in bars1 + bars2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')
ax.set_ylabel('NSE Value')
ax.set_title('Median and Mean NSE Comparison between LSTM Combined and Upstream Models (n10)')
ax.legend()
plt.tight_layout()
plt.show()

# %%
n5_median_and_mean_NSE_combined = [0.55, -7.2]
n10_median_and_mean_NSE_combined = [0.4482, -11.3082]

x = ['n5', 'n10']
median_values = [n5_median_and_mean_NSE_combined[0], n10_median_and_mean_NSE_combined[0]]
mean_values = [n5_median_and_mean_NSE_combined[1], n10_median_and_mean_NSE_combined[1]]
bar_width = 0.35
fig, ax = plt.subplots()
bars1 = ax.bar(x, median_values, bar_width, label='Median NSE', color='#66b3ff')
bars2 = ax.bar([i + bar_width for i in range(len(x))], mean_values, bar_width, label='Mean NSE', color='#ff9999') 
# Add value labels on top of bars
for bar in bars1 + bars2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')
ax.set_ylabel('NSE Value')
ax.set_title('Median and Mean NSE Comparison for LSTM Combined Model (n5 vs n10)')
ax.legend()
plt.tight_layout()
plt.show()
